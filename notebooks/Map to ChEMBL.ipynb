# %%
from bio2bel_sider.parser import get_indications_df, get_drug_names_df
from bio2bel_sider.utils import (
    convert_flat_stitch_id_to_pubchem_cid, 
    enrich_pubchem_synonyms, 
    get_chembl,
)
import pandas as pd
import os
from tqdm import tqdm_notebook as tqdm

# %%
indications_df = get_indications_df()
drug_names_df = get_drug_names_df()

df = pd.merge(indications_df, drug_names_df, on='STITCH_FLAT_ID')
df.head()
# Out:
#   STITCH_FLAT_ID UMLS CUI from Label Method of Detection  \
# 0   CID100000085            C0015544        text_mention
# 1   CID100000085            C0015544        text_mention
# 2   CID100000085            C0020615        text_mention
# 3   CID100000085            C0020615        text_mention
# 4   CID100000085            C0022661      NLP_indication
#
#               Concept Name MedDRA Concept Type UMLS CUI from MedDRA  \
# 0        Failure to Thrive                 LLT             C0015544
# 1        Failure to Thrive                  PT             C0015544
# 2             Hypoglycemia                 LLT             C0020615
# 3             Hypoglycemia                  PT             C0020615
# 4  Kidney Failure, Chronic                 LLT             C0022661
#
#      MedDRA Concept name  Drug Name
# 0      Failure to thrive  carnitine
# 1      Failure to thrive  carnitine
# 2          Hypoglycaemia  carnitine
# 3          Hypoglycaemia  carnitine
# 4  Renal failure chronic  carnitine

# %%
df['pubchem_cid'] = df['STITCH_FLAT_ID'].map(convert_flat_stitch_id_to_pubchem_cid)
df.head()
# Out:
#   STITCH_FLAT_ID UMLS CUI from Label Method of Detection  \
# 0   CID100000085            C0015544        text_mention
# 1   CID100000085            C0015544        text_mention
# 2   CID100000085            C0020615        text_mention
# 3   CID100000085            C0020615        text_mention
# 4   CID100000085            C0022661      NLP_indication
#
#               Concept Name MedDRA Concept Type UMLS CUI from MedDRA  \
# 0        Failure to Thrive                 LLT             C0015544
# 1        Failure to Thrive                  PT             C0015544
# 2             Hypoglycemia                 LLT             C0020615
# 3             Hypoglycemia                  PT             C0020615
# 4  Kidney Failure, Chronic                 LLT             C0022661
#
#      MedDRA Concept name  Drug Name pubchem_cid
# 0      Failure to thrive  carnitine          85
# 1      Failure to thrive  carnitine          85
# 2          Hypoglycaemia  carnitine          85
# 3          Hypoglycaemia  carnitine          85
# 4  Renal failure chronic  carnitine          85

# %%
path = 'pubchem_cid_to_chembl.tsv'
checked = {}
if not os.path.exists(path):
    checked = {}
else:
    with open(path) as file:
        checked = dict(
            line.split('\t')
            for line in file
        )

missing_pubchem_cids = set()
with open(path, 'w+') as file:
    for pubchem_cid, chembl_id in checked.items():
        print(pubchem_cid, chembl_id, sep='\t', file=file)
    
    it = tqdm(df.pubchem_cid.unique())
    for pubchem_cid in it:
        try:
            chembl_id = get_chembl(pubchem_cid)
        except Exception:
            it.write(f"exception for {pubchem_cid}")
            continue

        if chembl_id is None:
            it.write(f"can't find {pubchem_cid}")
            missing_pubchem_cids.add(pubchem_cid)
            continue

        print(pubchem_cid, chembl_id, sep='\t', file=file)
# Out:
# HBox(children=(IntProgress(value=0, max=1360), HTML(value='')))
# can't find 143
# can't find 158
# can't find 159
# can't find 206
# can't find 214
# can't find 232
# can't find 271
# can't find 699
# can't find 772
# can't find 813
# can't find 888
# can't find 923
# can't find 937
# can't find 1003
# can't find 1071
# can't find 1125
# can't find 1206
# can't find 1690
# can't find 1798
# can't find 1875
# can't find 1971
# can't find 2022
# can't find 2085
# can't find 2094
# can't find 2133
# can't find 2142
# can't find 2156
# can't find 2163
# can't find 2168
# can't find 2171
# can't find 2173
# can't find 2182
# can't find 2232
# can't find 2250
# can't find 2269
# can't find 2274
# can't find 2308
# can't find 2350
# can't find 2443
# can't find 2487
# can't find 2522
# can't find 2524
# can't find 2559
# can't find 2617
# can't find 2622
# can't find 2631
# can't find 2637
# can't find 2650
# can't find 2654
# can't find 2655
# can't find 2656
# can't find 2658
# can't find 2675
# can't find 2676
# can't find 2713
# can't find 2751
# can't find 2767
# can't find 2791
# can't find 2792
# can't find 2818
# can't find 2881
# can't find 2891
# can't find 2909
# can't find 2914
# can't find 2949
# can't find 2951
# can't find 2978
# can't find 3000
# can't find 3015
# can't find 3032
# can't find 3040
# can't find 3043
# can't find 3056
# can't find 3060
# can't find 3063
# can't find 3075
# can't find 3143
# can't find 3155
# can't find 3199
# can't find 3249
# can't find 3256
# can't find 3263
# can't find 3268
# can't find 3325
# can't find 3340
# can't find 3355
# can't find 3379
# can't find 3382
# can't find 3387
# can't find 3392
# can't find 3399
# can't find 3405
# can't find 3414
# can't find 3419
# can't find 3443
# can't find 3454
# can't find 3462
# can't find 3553
# can't find 3648
# can't find 3706
# can't find 3734
# can't find 3777
# can't find 3780
# can't find 3890
# can't find 3911
# can't find 3916
# can't find 3928
# can't find 3938
# can't find 3939
# can't find 3954
# can't find 3961
# can't find 3962
# can't find 4042
# can't find 4043
# can't find 4048
# can't find 4160
# can't find 4163
# can't find 4196
# can't find 4240
# can't find 4248
# can't find 4253
# can't find 4259
# can't find 4264
# can't find 4272
# can't find 4411
# can't find 4419
# can't find 4422
# can't find 4432
# can't find 4473
# can't find 4536
# can't find 4542
# can't find 4568
# can't find 4585
# can't find 4607
# can't find 4609
# can't find 4623
# can't find 4635
# can't find 4638
# can't find 4666
# can't find 4673
# can't find 4675
# can't find 4689
# can't find 4725
# can't find 4730
# can't find 4739
# can't find 4745
# can't find 4812
# can't find 4819
# can't find 4829
# can't find 4834
# can't find 4896
# can't find 4923
# can't find 5005
# can't find 5051
# can't find 5076
# can't find 5106
# can't find 5212
# can't find 5214
# can't find 5372
# can't find 5407
# can't find 5409
# can't find 5470
# can't find 5486
# can't find 5508
# can't find 5514
# can't find 5544
# can't find 5582
# can't find 5645
# can't find 5647
# can't find 5672
# can't find 5721
# can't find 5727
# can't find 5734
# can't find 5939
# can't find 8230
# can't find 12453
# can't find 12536
# can't find 14789
# can't find 14888
# can't find 19090
# can't find 20585
# can't find 22258
# can't find 22318
# can't find 23703
# can't find 23925
# can't find 23951
# can't find 23954
# can't find 23957
# can't find 23976
# can't find 23978
# can't find 23982
# can't find 23994
# can't find 24642
# can't find 24748
# can't find 27993
# can't find 28332
# can't find 29089
# can't find 32281
# can't find 32603
# can't find 32797
# can't find 37720
# can't find 38904
# can't find 39524
# can't find 42615
# can't find 42955
# can't find 45469
# can't find 47419
# can't find 47640
# can't find 50614
# can't find 52421
# can't find 54313
# can't find 54373
# can't find 54547
# can't find 54786
# can't find 54808
# can't find 54949
# can't find 55466
# can't find 55480
# can't find 57166
# can't find 60146
# can't find 60183
# can't find 60184
# can't find 60668
# can't find 60695
# can't find 60706
# can't find 60714
# can't find 60754
# can't find 60830
# can't find 60843
# can't find 60864
# can't find 60878
# can't find 62305
# can't find 62816
# can't find 62819
# can't find 62924
# can't find 63001
# can't find 64147
# can't find 64778
# can't find 65281
# can't find 65370
# can't find 65840
# can't find 68613
# can't find 71273
# can't find 71316
# can't find 71348
# can't find 71406
# can't find 71436
# can't find 72054
# can't find 72466
# can't find 72938
# can't find 73658
# can't find 77996
# can't find 77998
# can't find 78032
# can't find 83030
# can't find 83606
# can't find 102258
# can't find 102399
# can't find 104758
# can't find 104778
# can't find 105145
# can't find 107694
# can't find 110634
# can't find 119212
# can't find 119830
# can't find 122197
# can't find 122316
# can't find 123597
# can't find 123610
# can't find 123611
# can't find 123620
# can't find 123623
# can't find 123634
# can't find 123809
# can't find 127909
# can't find 128549
# can't find 129806
# can't find 135113
# can't find 148127
# can't find 148191
# can't find 150310
# can't find 151165
# can't find 152945
# can't find 153941
# can't find 156326
# can't find 157429
# can't find 157688
# can't find 158786
# can't find 159247
# can't find 160036
# can't find 160051
# can't find 160352
# can't find 168625
# can't find 168924
# can't find 171558
# can't find 192155
# can't find 197281
# can't find 206527
# can't find 213023
# can't find 216209
# can't find 216258
# can't find 219090
# can't find 315411
# can't find 441332
# can't find 441382
# can't find 443379
# can't find 444013
# can't find 444033
# can't find 455658
# can't find 3006171
# can't find 3055172
# can't find 3080904
# can't find 3081276
# can't find 3081884
# can't find 3086257
# can't find 3325225
# can't find 4474778
# can't find 4479094
# can't find 4479097
# can't find 4517618
# can't find 4630253
# can't find 4659568
# can't find 5001396
# can't find 5273759
# can't find 5281007
# can't find 5327147
# can't find 5353894
# can't find 5353980
# can't find 5360237
# can't find 5361912
# can't find 5362070
# can't find 5381226
# can't find 5462337
# can't find 5479141
# can't find 5487068
# can't find 5487301
# can't find 5488383
# can't find 5493381
# can't find 6102852
# can't find 6323497
# can't find 6328144
# can't find 6331630
# can't find 6333887
# can't find 6433091
# can't find 6433101
# can't find 6433117
# can't find 6435110
# can't find 6440191
# can't find 6452749
# can't find 6453361
# can't find 6477186
# can't find 6850789
# can't find 6850791
# can't find 6918366
# can't find 6918430
# can't find 9810131
# can't find 9811221
# can't find 9812414
# can't find 9815559
# can't find 9825285
# can't find 9831761
# can't find 9831783
# can't find 9846180
# can't find 9940864
# can't find 10028615
# can't find 11020241
# can't find 11163584
# can't find 11228026
# can't find 11235728
# can't find 11238823
# can't find 11254352
# can't find 11505907
# can't find 11593706
# can't find 11672461
# can't find 11947681
# can't find 11979316
# can't find 16065945
# can't find 16129616
# can't find 16129617
# can't find 16129629
# can't find 16129665
# can't find 16129672
# can't find 16129682
# can't find 16129690
# can't find 16129701
# can't find 16129703
# can't find 16131310
# can't find 16132265
# can't find 16132283
# can't find 16132344
# can't find 16132418
# can't find 16132438
# can't find 16132441
# can't find 16132446
# can't find 16134956
# can't find 16139342
# can't find 16139605
# can't find 16156130
# can't find 16158473
# can't find 22834577
# can't find 23689036
# can't find 23690938
# can't find 24762228
# can't find 24838347
# can't find 24846132
# can't find 24950485
# can't find 25074886
# can't find 25077405
# can't find 25094462
# can't find 25880656
# can't find 25880664
# can't find 26275995
# can't find 40468184
# can't find 44134877
# can't find 44146714
# can't find 44201342
# can't find 44201343
# can't find 44564722
# can't find 44567678
# can't find 46181941
# can't find 51508717
# can't find 51601240
# can't find 53477714
# can't find 53627505
# can't find 54681041
# can't find 54682541
# can't find 54687131
# can't find 56603655
# can't find 56842239
# can't find 71306834

# %%
print(f'could not find {len(missing_pubchem_cids)}/{len(df.pubchem_cid.unique())} ChEMBL mappings')
# Out:
# could not find 430/1360 ChEMBL mappings
